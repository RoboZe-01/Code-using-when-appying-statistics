# %%
# Generate sample

import numpy  as np 
import matplotlib.pyplot as plt
from numpy.random import normal

import pandas as pd
sample1 = normal(loc = 20 , scale = 5, size = 300)
sample2 = normal(loc = 50 , scale = 5, size = 700)
sample = np.hstack((sample1, sample2))




sample

len(sample)
# Out:
# 1000

# %%
# Plot histograms of bins = 50 

plt.hist(sample, bins = 50 )
# Out:
# (array([ 2.,  2.,  9., 10., 11.,  9., 23., 31., 21., 29., 26., 27., 22.,
#         17., 15., 12.,  8.,  7.,  6.,  6.,  5.,  1.,  1.,  0.,  0.,  3.,
#          4.,  4., 13., 24., 10., 21., 35., 43., 34., 57., 53., 57., 58.,
#         70., 63., 36., 28., 27., 22., 16.,  9.,  7.,  4.,  2.]),
#  array([ 8.53009339,  9.63364047, 10.73718755, 11.84073463, 12.94428171,
#         14.04782879, 15.15137587, 16.25492295, 17.35847003, 18.46201711,
#         19.56556419, 20.66911127, 21.77265836, 22.87620544, 23.97975252,
#         25.0832996 , 26.18684668, 27.29039376, 28.39394084, 29.49748792,
#         30.601035  , 31.70458208, 32.80812916, 33.91167624, 35.01522332,
#         36.1187704 , 37.22231748, 38.32586456, 39.42941164, 40.53295872,
#         41.6365058 , 42.74005288, 43.84359996, 44.94714705, 46.05069413,
#         47.15424121, 48.25778829, 49.36133537, 50.46488245, 51.56842953,
#         52.67197661, 53.77552369, 54.87907077, 55.98261785, 57.08616493,
#         58.18971201, 59.29325909, 60.39680617, 61.50035325, 62.60390033,
#         63.70744741]),
#  <BarContainer object of 50 artists>)
